# %%
import pandas as pd

# %%
df=pd.read_excel(r"studentdata.xlsx")

# %%
print(df)
# Out:
#      S/N             student_names  age weight   height
# 0    1.0            Adokorac Nancy   20     74    177.8
# 1    2.0   Amutuhaire Faith Ahabwe   27     47   157.48
# 2    3.0     KWAGALA JOANNA VICTOR   21     54   185.42
# 3    4.0              mahoro cathy   23     30   185.42
# 4    5.0  Mbabazi Hawa Bint Edrisa   19     59   175.26
# 5    6.0       Nakanjako josephine   24     65   175.26
# 6    7.0            Nanteza Dorcus   21     69   157.48
# 7    8.0             Mbabazi Angel   19     57   167.64
# 8    9.0            Namara Racheal   19     55   154.94
# 9   10.0       Lwamulungi Sheillah   22     78   162.56
# 10   NaN           Nakawuka Sandra   25     60   175.26
# 11   NaN   Achola Gloria Fortunate   27     80   172.72
# 12   NaN             Nagawa Esther   21     58   188.42
# 13   NaN           wanjiku hananny   19     50    165.1
# 14   NaN            babirye Sandra   21     50   175.26
# 15   NaN          nakagga shanitah   21     50   175.26
# ...

# %%
import matplotlib.pyplot as plt

# %%
w = df['weight']
h = df['height']
# changing the datatype of height to a string type
h = h.astype('str')
print(type(h))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# SCATTER DIAGRAM
#
# plotting a scatter diagram to represent a relationship between height and weight of students

# %%
import numpy as np

# %%
plt.plot(h,w, 'o' )
# the represents the dot plotting
#find line of best fit

# %%
# alpha reduces or increases the size/visibilty of the dot of the dot
plt.plot( h, w, 'o', alpha=0.5)

# %%
plt.title("Relationship between weight and height in Cohort 3")
plt.xlabel("weight in kg")
plt.ylabel("height in cm")
# Out:
# Text(0, 0.5, 'height in cm')

# %% [markdown]
# VIOLIN PLOT

# %%
df
# Out:
#    weight   height  age
# 0      74    177.8   20
# 1      47   157.48   27
# 2      54   185.42   21
# 3      30   185.42   23
# 4      59   175.26   19
# 5      65   175.26   24
# 6      69   157.48   21
# 7      57   167.64   19
# 8      55   154.94   19
# 9      78   162.56   22
# 10     60   175.26   25
# 11     80   172.72   27
# 12     58   188.42   21
# 13     50    165.1   19
# 14     50   175.26   21
# 15     50   175.26   21
# 16     49   160.02   20
# 17     70   162.56   23
# 18     62    101.6   20
# 19     55   162.56   20
# 20     55    93.98   27
# 21     60    165.1   23
# 22     45     63.5   21
# 23     70    101.6   19
# 24     55   170.18   20
# 25     67   175.26   22
# 26     67   137.16   21
# 27     64    165.1   23
# 28     50   157.48   20
# 29     65   104.14   30
# 30     52   170.18   23
# 31     50   162.56   24

# %%
import seaborn as sns

# %%
age = df['age']

# %%
weight = df['weight']

# %%
sns.violinplot(x=age, y=weight, inner=None)
plt.show()

# %% [markdown]
# BOX PLOT

# %%
sns.boxplot(x=age, y=weight)
# Out:
# <Axes: xlabel='age', ylabel='weight'>

# %% [markdown]
# CORRELATION
#
# choose 3 variables and decode them under columns

# %%
# decoding the data
columns =["age", "weight", "height"]

# %%
height=df['height']

# %%
df1=df[columns]

# %%
df1.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15888\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#      age
# age  1.0
